# %% [markdown]
# # OECD data processing

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})

# %%
fbornpop = pd.read_csv('csv/OECD_fbornpop.csv', encoding='utf-8-sig')

# %%
fbornpop.columns.values[0]

fbornpop.columns = map(lambda x: x.replace('"', ''), fbornpop.columns)

# %%
## 2012 is the year from which we have the best and latest accounts.
fbornpop_2012 = fbornpop[fbornpop['TIME'] == 2012]

# %%
sns.barplot(x="LOCATION", y="Value", data=fbornpop_2012);

# %%
res
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value  Flag Codes
# 24       AUS  FBORNPOP     TOT  PC_POP         A  2013  27.600         NaN
# 44       BEL  FBORNPOP     TOT  PC_POP         A  2013  15.500         NaN
# 70       CAN  FBORNPOP     TOT  PC_POP         A  2013  20.000         NaN
# 95       DNK  FBORNPOP     TOT  PC_POP         A  2013   8.500         NaN
# 114      FIN  FBORNPOP     TOT  PC_POP         A  2013   5.600         NaN
# 133      DEU  FBORNPOP     TOT  PC_POP         A  2013  12.800         NaN
# 152      HUN  FBORNPOP     TOT  PC_POP         A  2013   4.500         NaN
# 172      LUX  FBORNPOP     TOT  PC_POP         A  2013  43.700         NaN
# 188      MEX  FBORNPOP     TOT  PC_POP         A  2013   0.800         NaN
# 210      NLD  FBORNPOP     TOT  PC_POP         A  2013  11.600         NaN
# 234      NOR  FBORNPOP     TOT  PC_POP         A  2013  13.900         NaN
# ...

# %%
stats.shapiro(fbornpop_2012["Value"])
# Out:
# (0.9071416258811951, 0.014585934579372406)
